# %%
from qdrant_client import QdrantClient, models

class QdrantVectorStore:
    def __init__(self, host: str):
        self.client = QdrantClient(url=host)

    def create_collection(self, collection_name: str, embedding_dimensionality: int):
        if not self.client.collection_exists(collection_name=collection_name):
            self.client.create_collection(collection_name=collection_name,
                                        vectors_config=models.VectorParams(
                                            size=embedding_dimensionality,
                                            distance=models.Distance.COSINE
                                        )
                                        )
        else:
            print(f"Collection {collection_name} already exists.")

    def create_collection_sparse(self, collection_name: str):
        if not self.client.collection_exists(collection_name=collection_name):
            self.client.create_collection(
                collection_name=collection_name,
                sparse_vectors_config={
                    "bm25": models.SparseVectorParams(
                        modifier=models.Modifier.IDF
                    )
                }
            )
        else:
            print(f"Collection {collection_name} already exists.")
            
    def create_collection_hybrid(self, collection_name: str, embedding_dimensionality: int):
        if not self.client.collection_exists(collection_name=collection_name):
            self.client.create_collection(
                collection_name=collection_name,
                vectors_config={
                    "jina-small": models.VectorParams(
                        size=embedding_dimensionality,
                        distance=models.Distance.COSINE
                    )
                },
                sparse_vectors_config={
                    "bm25": models.SparseVectorParams(
                        modifier=models.Modifier.IDF
                    )
                }
            )
        else:
            print(f"Collection {collection_name} already exists.")

# %%
import uuid
from qdrant_client import models

def upsert_sparse_dense_documents(client, collection_name: str, model_handle_dense: str, model_handle_sparse: str, documents: list):
    client.upsert(
        collection_name=collection_name,
        points=[
            models.PointStruct(
                id=uuid.uuid4().hex,
                vector={
                    "jina-small": models.Document(
                        text=doc["text"],
                        model=model_handle_dense
                        ),
                    "bm25": models.Document(
                        text=doc["text"],
                        model=model_handle_sparse
                        )
                    },
                payload={
                    "text": doc["text"],
                    "section": doc["section"],
                    "course": doc['course'],
                    "question": doc["question"],
                    "id": doc["document_id"]
                }
            )
        for doc in documents
        ]
    )

# %%
def search_multi_stage_sparse_and_dense(query: str, client, collection_name, limit: int) -> list[models.ScoredPoint]:
    
    results = client.query_points(
        collection_name=collection_name,
        prefetch=[
            models.Prefetch(
                query=models.Document(
                    text=query,
                    model="jinaai/jina-embeddings-v2-small-en"
                ),
                using='jina-small',
                limit=(limit*5)
            )
        ],
        query=models.Document(
            text=query,
            model="Qdrant/bm25"
        ),
        limit=limit,
        using="bm25",
        with_payload=True
    )
    return results.points

def search_hybrid(query: str, client, collection_name: str, limit: int=1) -> list[models.ScoredPoint]:
    
    results = client.query_points(
        collection_name=collection_name,
        prefetch=[
            models.Prefetch(
                query=models.Document(
                    text=query,
                    model="jinaai/jina-embeddings-v2-small-en"
                ),
                using='jina-small',
                limit=(limit*5)
            ),
            models.Prefetch(
                query=models.Document(
                    text=query,
                    model="Qdrant/bm25"
                ),
                using="bm25",
                limit=(limit*5)
            )
        ],
        query=models.FusionQuery(
            fusion=models.Fusion.RRF
        ),
        with_payload=True,
    )
    return results.points

# %%
import json
with open('./documents-with-ids-updated.json', 'rt') as f_in:
    documents = json.load(f_in)

# %%
host = "http://localhost:6333"
collection_name = "nakul-zoomcamp-faq-collection"

# %%
qv = QdrantVectorStore(host=host)
qv.create_collection_hybrid(collection_name=collection_name, embedding_dimensionality=512)
# Out:
# Collection nakul-zoomcamp-faq-collection already exists.

# %%
# Adding documents to the vector store
upsert_sparse_dense_documents(client=qv.client,
                              collection_name=collection_name,
                              model_handle_dense="jinaai/jina-embeddings-v2-small-en",
                              model_handle_sparse="Qdrant/bm25",
                              documents=documents
                             )

# %%
data = search_hybrid("when does the course start", 
              client=qv.client, 
              collection_name=collection_name,
              limit=5)
for point in data:
    print(point.payload)
# Out:
# {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.", 'section': 'General course-related questions', 'course': 'data-engineering-zoomcamp', 'question': 'Course - When will the course start?', 'id': '12ba9d1bc6ca27c5'}
# {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.", 'section': 'General course-related questions', 'course': 'data-engineering-zoomcamp', 'question': 'Course - When will the course start?', 'id': '12ba9d1bc6ca27c5'}
# {'text': 'The course is available in the self-paced mode too, so you can go through the materials at any time. But if you want to do it as a cohort with other students, the next iterations will happen in September 2023, September 2024 (and potentially other Septembers as well).', 'section': 'General course-related questions', 'course': 'machine-learning-zoomcamp', 'question': 'When does the next iteration start?', 'id': '7a3f52d1690f38b6'}
# {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.", 'section': 'General course-related questions', 'course': 'data-engineering-zoomcamp', 'question': 'Course - When will the course start?', 'id': '12ba9d1bc6ca27c5'}
# {'text': 'The course is available in the self-paced mode too, so you can go through the materials at any time. But if you want to do it as a cohort with other students, the next iterations will happen in September 2023, September 2024 (and potentially other Septembers as well).', 'section': 'General course-related questions', 'course': 'machine-learning-zoomcamp', 'question': 'When does the next iteration start?', 'id': '7a3f52d1690f38b6'}
# {'text': 'Welcome to the course! Go to the course page (http://mlzoomcamp.com/), scroll down and start going through the course materials. Then read everything in the cohort folder for your cohort’s year.\nClick on the links and start watching the videos. Also watch office hours from previous cohorts. Go to DTC youtube channel and click on Playlists and search for {course yyyy}. ML Zoomcamp was first launched in 2021.\nOr you can just use this link: http://mlzoomcamp.com/#syllabus', 'section': 'General course-related questions', 'course': 'machine-learning-zoomcamp', 'question': 'I just joined. What should I do next? How can I access course materials?', 'id': '9b2c24c96ccd9160'}
# {'text': 'The course is available in the self-paced mode too, so you can go through the materials at any time. But if you want to do it as a cohort with other students, the next iterations will happen in September 2023, September 2024 (and potentially other Septembers as well).', 'section': 'General course-related questions', 'course': 'machine-learning-zoomcamp', 'question': 'When does the next iteration start?', 'id': '7a3f52d1690f38b6'}
# {'text': 'The course videos are pre-recorded, you can start watching the course right now.\nWe will also occasionally have office hours - live sessions where we will answer your questions. The office hours sessions are recorded too.\nYou can see the office hours as well as the pre-recorded course videos in the course playlist on YouTube.', 'section': 'General course-related questions', 'course': 'machine-learning-zoomcamp', 'question': 'Is it going to be live? When?', 'id': '96c8e11cdcee8413'}
# {'text': 'Welcome to the course! Go to the course page (http://mlzoomcamp.com/), scroll down and start going through the course materials. Then read everything in the cohort folder for your cohort’s year.\nClick on the links and start watching the videos. Also watch office hours from previous cohorts. Go to DTC youtube channel and click on Playlists and search for {course yyyy}. ML Zoomcamp was first launched in 2021.\nOr you can just use this link: http://mlzoomcamp.com/#syllabus', 'section': 'General course-related questions', 'course': 'machine-learning-zoomcamp', 'question': 'I just joined. What should I do next? How can I access course materials?', 'id': '9b2c24c96ccd9160'}
# {'text': 'The course videos are pre-recorded, you can start watching the course right now.\nWe will also occasionally have office hours - live sessions where we will answer your questions. The office hours sessions are recorded too.\nYou can see the office hours as well as the pre-recorded course videos in the course playlist on YouTube.', 'section': 'General course-related questions', 'course': 'machine-learning-zoomcamp', 'question': 'Is it going to be live? When?', 'id': '96c8e11cdcee8413'}

# %%
import pandas as pd

# %%
df_ground_truth = pd.read_csv('ground-truth-data-practice.csv')
ground_truth = df_ground_truth.to_dict(orient='records')

# %%
df_ground_truth.head()
# Out:
#                                             question  \
# 0  Could you let me know the specific date and ti...
# 1  What is the starting date for the first live O...
# 2  Is there a way to add the course schedule to m...
# 3  When exactly should I register for the course ...
# 4  How do I stay updated with announcements regar...
#
#                       course          document
# 0  data-engineering-zoomcamp  12ba9d1bc6ca27c5
# 1  data-engineering-zoomcamp  12ba9d1bc6ca27c5
# 2  data-engineering-zoomcamp  12ba9d1bc6ca27c5
# 3  data-engineering-zoomcamp  12ba9d1bc6ca27c5
# 4  data-engineering-zoomcamp  12ba9d1bc6ca27c5

# %%
from tqdm.auto import tqdm

# %%
relevance_total = []
for q in tqdm(ground_truth):
    doc_id = q['document']
    results = search_hybrid(query=q['question'], 
              client=qv.client, 
              collection_name=collection_name,
              limit=1)
    relevance = [point.payload['id'] == doc_id for point in results]
    relevance_total.append(relevance)
# Out:
#   0%|          | 0/4119 [00:00<?, ?it/s]

# %%
def hit_rate(relevance_total):
    counter = 0
    for ls in relevance_total:
        if sum(ls) > 0:
            counter += 1
    return counter/len(relevance_total)

# %%
hit_rate(relevance_total=relevance_total)
# Out:
# 0.8040786598689003

# %%
def mrr(relevance_total):
    score = 0.0
    for ls in relevance_total:
        for rank in range(len(ls)):
            if ls[rank]:
                score = score + (1/(rank+1))
                break
    return score/len(relevance_total)

# %%
mrr(relevance_total)
# Out:
# 0.6715092081989401

# %%
def evaluate(ground_truth, search_function, collection_name, client):
    relevance_total = []
    for q in tqdm(ground_truth):
        doc_id = q['document']
        results = search_function(query=q['question'], 
                  client=qv.client, 
                  collection_name=collection_name,
                  limit=5)
        relevance = [point.payload['id'] == doc_id for point in results]
        relevance_total.append(relevance)

    return {'hit_rate': hit_rate(relevance_total=relevance_total),
            'mrr': mrr(relevance_total=relevance_total)}

# %%
# hybrid search
evaluate(
    ground_truth=ground_truth,
    search_function=search_hybrid,
    collection_name=collection_name,
    client=qv.client)
# Out:
#   0%|          | 0/4119 [00:00<?, ?it/s]
# {'hit_rate': 0.822044185481913, 'mrr': 0.6888098899023883}

# %%
# sparse and dense search
evaluate(
    ground_truth=ground_truth,
    search_function=search_multi_stage_sparse_and_dense,
    collection_name=collection_name,
    client=qv.client)
# Out:
#   0%|          | 0/4119 [00:00<?, ?it/s]
# {'hit_rate': 0.71546491866958, 'mrr': 0.6177267945294165}

# %%
# Lets calculate cosine similarity
# -> We need to create answers for each question
# -> Then we need to do cosine similar score for each answer with original question answer

# %%
for q in range(0, len(ground_truth)):
    search = search_hybrid(query=ground_truth[q]['question'], client=qv.client, collection_name=collection_name, limit=1)
    answer = (search[0].payload['text'])
    ground_truth[q]['answer'] = answer

# %%
ground_truth[3]
# Out:
# {'question': 'When exactly should I register for the course to ensure my spot?',
#  'course': 'data-engineering-zoomcamp',
#  'document': '12ba9d1bc6ca27c5',
#  'answer': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date."}

# %%
documents[3]
# Out:
# {'text': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#  'section': 'General course-related questions',
#  'question': 'Course - I have registered for the Data Engineering Bootcamp. When can I expect to receive the confirmation email?',
#  'course': 'data-engineering-zoomcamp',
#  'document_id': '561fbba60a8a1668'}

# %%
import pickle

# %%
with open('./results_practice.bin', 'rb') as f_in:
    data = pickle.load(f_in)

# %%
from collections import defaultdict

# %%
hashes = defaultdict(list)

for doc in documents:
    doc_id = doc['document_id']
    hashes[doc_id].append(doc)

# %%
from sentence_transformers import SentenceTransformer

model_name = 'multi-qa-MiniLM-L6-cos-v1'
model = SentenceTransformer(model_name)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/383 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
scores = []
for q in ground_truth:
    vector_answer = model.encode(q["answer"])
    original_answer = model.encode(hashes[q['document']][0]['text'])
    score = vector_answer.dot(original_answer)
    scores.append(score)

# %%
cosine_score = sum(scores)/len(scores)
print(f"cosine similarity for retrieving data from vector store is {cosine_score}")
# Out:
# cosine similarity for retrieving data from vector store is 0.7463263273239136

# %%
import time
import os
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
from tqdm.auto import tqdm
from test_functions import sum_of_squares
from rag_functions import OpenAIClient, build_context

# %%
numbers = [100000000, 20000000, 100000000, 15000000, 20000000]

# %%
start = time.time()
for num in numbers:
    print(sum_of_squares(num))
end = time.time()
print(f"time taken {end - start:.2f} seconds")
# Out:
# 333333328333333350000000
# 2666666466666670000000
# 333333328333333350000000
# 1124999887500002500000
# 2666666466666670000000
# time taken 11.94 seconds

# %%
start = time.time()
with ProcessPoolExecutor(max_workers=5) as executor:
    results = list(executor.map(sum_of_squares, numbers))
end = time.time()
print(results)
print(f"time taken {end - start:.2f} seconds")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [333333328333333350000000, 2666666466666670000000, 333333328333333350000000, 1124999887500002500000, 2666666466666670000000]
# time taken 5.31 seconds

# %%
start = time.time()
with ThreadPoolExecutor(max_workers=5) as executor:
    results = list(executor.map(sum_of_squares, numbers))
end = time.time()
print(results)
print(f"time taken {end - start:.2f} seconds")
# Out:
# [333333328333333350000000, 2666666466666670000000, 333333328333333350000000, 1124999887500002500000, 2666666466666670000000]
# time taken 12.07 seconds

# %%
# Lets do cosine similarity based on results from llm rag with vector store

# %%
MODEL = "gpt-4.1-nano"
prompt_template = """
You are a course assistant, and your goal is to answer questions of students, where QUESTION is provided below and CONTEXT is provided most of the times. 
Rules:
* Answer the QUESTION based on the CONTEXT.
* Use only the facts from the CONTEXT.
* If CONTEXT is empty, please let the student know, the information about their query is not there, however you found the following information on the web, by searching the web

QUESTION: {question}

CONTEXT: {context}
""".strip()

# %%
def rag(query):
    results = search_hybrid(query=query, collection_name=collection_name, client=qv.client, limit=2)

    # Build the context from the search results
    context = build_context(results)

    promt = prompt_template.format(question=query, context=context)

    client = OpenAIClient(api_key=os.getenv("OPENAI_API_KEY"), model=MODEL)

    # Send the prompt to the OpenAI API
    try:
        client_response = client.chat(query=promt)
    except RuntimeError:
        pass
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    return client_response

# %%
def process_record(rec):

    try:
        answer_llm = rag(rec['question'])
        doc_id = rec['document']
        original_answer = hashes[doc_id][0]['text']
        return {
            'answer_llm': answer_llm,
            'answer_orig': original_answer,
            'document': doc_id,
            'question': rec['question'],
            'course': rec['course']
        }
    except RuntimeError:
        pass

# %%
def make_progress(records, func):
    with tqdm(total=len(records), desc="Building context") as pbar:
        with ThreadPoolExecutor(max_workers=8) as executor:
            futures = [executor.submit(func, record) for record in records]
        
             # Iterate through completed futures using tqdm
            for future in as_completed(futures):
                pbar.update(1)
                yield future.result()

# %%
results = []
for result in make_progress(ground_truth[0:200], process_record):
    results.append(result)
# Out:
# Building context:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
for result in results:
    if result:
        vector_answer = model.encode(result['answer_llm'])
        original_answer = model.encode(result['answer_orig'])
        score = vector_answer.dot(original_answer)
        result['cosine_score'] = score

# %%
results_parsed = []
for result in results:
    if result:
        results_parsed.append(result)

# %%
df = pd.DataFrame(results_parsed)

# %%
df.cosine_score.describe()
# Out:
# count    189.000000
# mean       0.608616
# std        0.190586
# min        0.074563
# 25%        0.479401
# 50%        0.631104
# 75%        0.752846
# max        1.000000
# Name: cosine_score, dtype: float64

# %%
#llm as a judge

# %%
results_parsed
# Out:
# [{'answer_llm': 'The starting date for the first live Office Hours session of the course is not specified in the provided CONTEXT.',
#   'answer_orig': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#   'document': '12ba9d1bc6ca27c5',
#   'question': 'What is the starting date for the first live Office Hours session of the course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.61884654)},
#  {'answer_llm': 'The CONTEXT provided does not include specific information about the prerequisites necessary for participation in the "data-engineering-zoomcamp" course.',
#   'answer_orig': 'GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites',
#   'document': '550b6ff73abdf2f8',
#   'question': 'Can you list the prerequisites necessary for participation in this course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.63155454)},
#  {'answer_llm': 'The CONTEXT provided does not include specific information about the exact date and time when the course will begin. If you have access to the course registration or platform details, I recommend checking there for the precise start date and time.',
#   'answer_orig': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#   'document': '12ba9d1bc6ca27c5',
#   'question': 'Could you let me know the specific date and time when the course will begin?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.5463662)},
#  {'answer_llm': "To stay updated with announcements regarding the course, you should subscribe to the course's public Google Calendar (which works from a desktop), register before the course starts using the provided registration link, join the course's Telegram channel for announcements, and also register and join the DataTalks.Club's Slack channel.",
#   'answer_orig': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#   'document': '12ba9d1bc6ca27c5',
#   'question': 'How do I stay updated with announcements regarding the course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.7605907)},
#  {'answer_llm': 'The CONTEXT provided does not contain specific information about the exact timing or deadlines for course registration. Therefore, I cannot determine the precise date or deadline when you should register to secure your spot. \n\nI recommend checking the official course registration page or announcements related to the DataTalksClub Data Engineering Zoomcamp for the registration deadline.',
#   'answer_orig': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#   'document': '12ba9d1bc6ca27c5',
#   'question': 'When exactly should I register for the course to ensure my spot?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.46203452)},
#  {'answer_llm': 'The CONTEXT provided does not include specific information about the skills or knowledge required to enroll in the course "data-engineering-zoomcamp." \n\nBased on this, I would inform you that:\n\nThe provided information does not specify particular skills or knowledge needed for enrollment. \n\nHowever, generally, courses like this often expect participants to have basic familiarity with data concepts and some technical skills, but for precise prerequisites, you may need to refer to the official course description or enrollment page.',
#   'answer_orig': 'GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites',
#   'document': '550b6ff73abdf2f8',
#   'question': 'Are there any specific skills or knowledge required to enroll in this course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.5850903)},
#  {'answer_llm': 'The CONTEXT provided does not contain specific information about the prior experience required before starting the course "data-engineering-zoomcamp." \n\nBased on typical course structure and the absence of explicit prerequisites in the context, I recommend that students have some foundational knowledge in the following areas:\n- Basic programming skills (preferably Python)\n- Familiarity with command-line interfaces\n- Basic understanding of data formats (CSV, Parquet)\n- Some experience with cloud platforms or the willingness to learn them\n\nHowever, since this information isn\'t explicitly stated in the CONTEXT, you may want to consult the course syllabus or contact the course instructor for precise prerequisites.',
#   'answer_orig': 'GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites',
#   'document': '550b6ff73abdf2f8',
#   'question': 'What prior experience should I have before starting this course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.54881656)},
#  {'answer_llm': "Yes, you can still access the course materials even if you don't register on time, as the course is available in self-paced mode, allowing you to go through the materials at any time.",
#   'answer_orig': "Yes, even if you don't register, you're still eligible to submit the homeworks.\nBe aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.",
#   'document': '3762f7e98fd36bd9',
#   'question': 'Can I still access course materials if I dont register on time?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.42569655)},
#  {'answer_llm': 'Yes, there are deadlines for turning in the final projects. If you join after the start and miss the deadline, late submissions are generally not allowed. However, if the submission form is still open after the due date, you can still submit your project; you should confirm your submission by the date and time specified on the Course page.',
#   'answer_orig': "Yes, even if you don't register, you're still eligible to submit the homeworks.\nBe aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.",
#   'document': '3762f7e98fd36bd9',
#   'question': 'Are there any consequences for submitting final projects late if I join after the start?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.53555787)},
#  {'answer_llm': 'Based on the CONTEXT, it is not necessary to wait for a confirmation email after registering for the Data Engineering Bootcamp. In fact, you can start learning and submitting homework without registration, as registration is only used to gauge interest prior to the start date.',
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'document': '561fbba60a8a1668',
#   'question': 'Is it necessary to wait for a confirmation email after registering for the Data Engineering Bootcamp?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.5895277)},
#  {'answer_llm': 'Based on the provided context, you do not need to wait for further instructions after registering to start participating in the bootcamp. You are accepted, and you can begin learning and submitting homework immediately. Registration is mainly to gauge interest before the start date.',
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'document': '561fbba60a8a1668',
#   'question': 'Can I start participating in the bootcamp immediately after registering, or do I need to wait for further instructions?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.627435)},
#  {'answer_llm': "The purpose of the registration for the Data Engineering Bootcamp is primarily to gauge interest before the start date. It is not mandatory, as you don't need to register to start learning or submit homework, and registration is not checked against any registered list.",
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'document': '561fbba60a8a1668',
#   'question': 'What is the purpose of the registration for the Data Engineering Bootcamp if it is not mandatory?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.62096536)},
#  {'answer_llm': "Based on the CONTEXT, if you are late to join the course or to submit the final project, here is what you should keep in mind:\n\n- Late submissions are generally not allowed. However, if the submission form is still open after the due date, you can still submit your homework and should confirm your submission by the date and timestamp indicated on the Course page.\n- For the final project specifically, there are deadlines, and it is implied that late submissions are not accepted. Therefore, it’s best to submit on time to avoid missing out.\n- Even if you haven't registered initially, you're still eligible to submit homework, but you should be mindful of the deadlines for the final project, as leaving everything for the last minute is discouraged.\n\nIn summary, to avoid issues, aim to join and submit your final project before the deadline, as late submissions are generally not permitted once the submission window closes.",
#   'answer_orig': "Yes, even if you don't register, you're still eligible to submit the homeworks.\nBe aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.",
#   'document': '3762f7e98fd36bd9',
#   'question': 'What should I keep in mind regarding final project submissions if Im late to join?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.60599643)},
#  {'answer_llm': 'No, you do not need to be on a list to submit your homework for the bootcamp. You can start learning and submitting homework without registering, as submissions are not checked against any registered list. Registration is only intended to gauge interest before the start date.',
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'document': '561fbba60a8a1668',
#   'question': 'Do I need to be on a list to submit my homework for the bootcamp?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.7337847)},
#  {'answer_llm': 'Based on the provided CONTEXT, you do not need to receive formal confirmation or registration to begin the course content for the Data Engineering Bootcamp. You are allowed to start learning and submitting homework without registering, as registration is mainly for gauging interest and is not a requirement to access the course materials or participate in assignments.',
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'document': '561fbba60a8a1668',
#   'question': 'Am I allowed to begin the course content for the Data Engineering Bootcamp without receiving a confirmation?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.66903913)},
#  {'answer_llm': 'The provided CONTEXT does not specify any particular tools or accounts that you need to create ahead of time for the course. However, it mentions that you may need to adapt the course materials to AWS if using that platform and that managing AWS instances involves some setup, such as stopping instances when not in use to control costs, and possibly configuring your SSH settings. \n\nIf you plan to use AWS for your course projects, you should create an AWS account in advance. Additionally, it’s advisable to set up budget alerts on AWS to monitor costs. \n\nFor more detailed instructions, you can refer to setting up your AWS environment and managing costs as described in the course materials.',
#   'answer_orig': 'You can start by installing and setting up all the dependencies and requirements:\nGoogle cloud account\nGoogle Cloud SDK\nPython 3 (installed with Anaconda)\nTerraform\nGit\nLook over the prerequisites and syllabus to see if you are comfortable with these subjects.',
#   'document': '195959f49fcd0b4e',
#   'question': 'Are there specific tools or accounts I need to create ahead of time for the course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.44797543)},
#  {'answer_llm': "The CONTEXT does not provide specific prerequisites for the data-engineering-zoomcamp course. However, based on the nature of the course, it is generally recommended to review foundational skills in programming (such as Python or SQL), understanding of data structures, basic database concepts, and familiarity with command-line tools. If you need more detailed prerequisites, I suggest reviewing the course's official syllabus or enrollment page for tailored recommendations.",
#   'answer_orig': 'You can start by installing and setting up all the dependencies and requirements:\nGoogle cloud account\nGoogle Cloud SDK\nPython 3 (installed with Anaconda)\nTerraform\nGit\nLook over the prerequisites and syllabus to see if you are comfortable with these subjects.',
#   'document': '195959f49fcd0b4e',
#   'question': 'What prerequisites should I review to ensure Im ready for the course content?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.30844963)},
#  {'answer_llm': 'Based on the provided context, you do not need to take any specific steps to prepare for the course before it begins. Registration is not required to start learning or submit homework, as it is mainly used to gauge interest. Once the course starts, you can begin studying and working on assignments at your own pace. However, if you want to prepare your environment for the more advanced parts of the course, such as deploying machine learning models in week 5, it is recommended to set up a cloud environment (e.g., AWS EC2) following the guides provided. But overall, there are no mandatory steps you need to take before the course starts.',
#   'answer_orig': 'You can start by installing and setting up all the dependencies and requirements:\nGoogle cloud account\nGoogle Cloud SDK\nPython 3 (installed with Anaconda)\nTerraform\nGit\nLook over the prerequisites and syllabus to see if you are comfortable with these subjects.',
#   'document': '195959f49fcd0b4e',
#   'question': 'What steps should I take to prepare for the course before it begins?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.5445064)},
#  {'answer_llm': 'Based on the provided CONTEXT, there is no specific information about prerequisites or things you should familiarize yourself with before participating in the course. However, it is mentioned that you can choose your own platform and environment for the course, such as GitHub Codespaces, GCP VM, or your laptop, indicating some familiarity with computing environments could be helpful, but is not strictly necessary. \n\nIf you want to be well-prepared, it might be beneficial to have some basic understanding of programming (likely Python), machine learning fundamentals, and working with cloud platforms, but the course itself appears flexible regarding prior knowledge.',
#   'answer_orig': 'You can start by installing and setting up all the dependencies and requirements:\nGoogle cloud account\nGoogle Cloud SDK\nPython 3 (installed with Anaconda)\nTerraform\nGit\nLook over the prerequisites and syllabus to see if you are comfortable with these subjects.',
#   'document': '195959f49fcd0b4e',
#   'question': 'Is there anything I should familiarize myself with before participating in the course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.53122354)},
#  {'answer_llm': 'Based on the provided CONTEXT, there is no specific information about changes made in the tools used for the current cohort.',
#   'answer_orig': 'Yes. For the 2024 edition we are using Mage AI instead of Prefect and re-recorded the terraform videos, For 2023, we used Prefect instead of Airflow..',
#   'document': '68bdbc293178bb10',
#   'question': 'What changes have been made in the tools used for the current cohort?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.15759528)},
#  {'answer_llm': "There are 3 Zoom Camps scheduled throughout the year as of 2024. These include separate courses: Data-Engineering (January to April), MLOps (May to August), and Machine Learning (September to January). Each course has its own dedicated Zoom Camp, with only one live cohort per course annually. \n\nDifferent topics are offered for each Zoom Camp, corresponding to these specific courses.\n\nFor the DataEngineering Zoom Camp, the typical timeline for the live cohort is generally from January to April of the year.\n\nIf you're not interested in obtaining the certificate, you can enroll in any Zoom Camp at any time and take it at your own pace, outside of the scheduled live cohort.",
#   'answer_orig': "There are 3 Zoom Camps in a year, as of 2024. However, they are for separate courses:\nData-Engineering (Jan - Apr)\nMLOps (May - Aug)\nMachine Learning (Sep - Jan)\nThere's only one Data-Engineering Zoomcamp “live” cohort per year, for the certification. Same as for the other Zoomcamps.\nThey follow pretty much the same schedule for each cohort per zoomcamp. For Data-Engineering it is (generally) from Jan-Apr of the year. If you’re not interested in the Certificate, you can take any zoom camps at any time, at your own pace, out of sync with any “live” cohort.",
#   'document': 'be768af9219e013b',
#   'question': 'How many Zoom Camps are scheduled throughout the year?, Are there different topics for each Zoom Camp offered annually?, Is there a specific timeline for the DataEngineering Zoom Camp?, Can I enroll in a Zoom Camp outside of its scheduled live cohort?, How often do the Zoom Camps take place during the year?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.9408726)},
#  {'answer_llm': 'Based on the provided CONTEXT, there is no specific list of software or applications to set up prior to the course start. However, I can share information on commonly implied tools for this course:\n\n- **Docker:** Essential for deploying machine learning models, as seen in the instructions on executing commands within Docker containers.\n- **gcloud SDK:** Needed if working with Google Cloud Platform (GCP) resources, such as VM instances.\n- **Terminal software (e.g., ConEmu, mintty):** For running commands, especially on Windows, where issues like the "input device is not a TTY" can occur.\n- **GitHub:** For managing repositories, notes, and projects related to the course.\n\nPlease ensure you have these tools installed and configured, as they are referenced in various sections of the course materials.',
#   'answer_orig': 'You can start by installing and setting up all the dependencies and requirements:\nGoogle cloud account\nGoogle Cloud SDK\nPython 3 (installed with Anaconda)\nTerraform\nGit\nLook over the prerequisites and syllabus to see if you are comfortable with these subjects.',
#   'document': '195959f49fcd0b4e',
#   'question': 'Can you provide a list of software or applications to set up prior to the course start?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.4878083)},
#  {'answer_llm': 'Based on the provided context, there is no specific information about how the 2024 cohort differs in terms of technology from the 2023 cohort. The main difference highlighted relates to the course content updates, such as the Orchestration and Monitoring modules being re-recorded and the homeworks being changed for the 2023 cohort, but no details are given about technological differences specific to the 2024 cohort compared to 2023.',
#   'answer_orig': 'Yes. For the 2024 edition we are using Mage AI instead of Prefect and re-recorded the terraform videos, For 2023, we used Prefect instead of Airflow..',
#   'document': '68bdbc293178bb10',
#   'question': 'How does the 2024 cohort differ in terms of technology from 2023?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.2772659)},
#  {'answer_llm': "Based on the provided CONTEXT, there is no information indicating that the course recording methods have changed for this year's edition.",
#   'answer_orig': 'Yes. For the 2024 edition we are using Mage AI instead of Prefect and re-recorded the terraform videos, For 2023, we used Prefect instead of Airflow..',
#   'document': '68bdbc293178bb10',
#   'question': 'Did the course recording methods change for this years edition?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.40466902)},
#  {'answer_llm': 'The CONTEXT does not explicitly mention a "technological switch" for the new cohort. Based solely on the provided information, there is no specific detail about a main technological switch for the upcoming cohort. If you need more precise or different details, please let me know!',
#   'answer_orig': 'Yes. For the 2024 edition we are using Mage AI instead of Prefect and re-recorded the terraform videos, For 2023, we used Prefect instead of Airflow..',
#   'document': '68bdbc293178bb10',
#   'question': 'What is the main technological switch for the new cohort?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.14559814)},
#  {'answer_llm': 'Yes, you can work on assignments after the course has ended. The course materials are available in a self-paced mode, so you can access and review them at any time after the course finishes.',
#   'answer_orig': 'Yes, we will keep all the materials after the course finishes, so you can follow the course at your own pace after it finishes.\nYou can also continue looking at the homeworks and continue preparing for the next cohort. I guess you can also start working on your final capstone project.',
#   'document': '7bc493b31f7e84ed',
#   'question': 'Can I work on assignments after the course has ended?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.6558939)},
#  {'answer_llm': 'The provided CONTEXT does not contain any specific information regarding updates in the course content for 2024. \n\nBased on the available information, I recommend checking the course repository or official announcements for the most recent updates. If you need, I can help guide you on how to find such updates or suggest where to look for official course news.',
#   'answer_orig': 'Yes. For the 2024 edition we are using Mage AI instead of Prefect and re-recorded the terraform videos, For 2023, we used Prefect instead of Airflow..',
#   'document': '68bdbc293178bb10',
#   'question': 'Are there any significant updates in the course content for 2024?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.2486467)},
#  {'answer_llm': 'Yes, it is possible to access the course materials after the course is over. The materials are kept available so that you can follow the course at your own pace, review videos, work on homework, and prepare for future cohorts.',
#   'answer_orig': 'Yes, we will keep all the materials after the course finishes, so you can follow the course at your own pace after it finishes.\nYou can also continue looking at the homeworks and continue preparing for the next cohort. I guess you can also start working on your final capstone project.',
#   'document': '7bc493b31f7e84ed',
#   'question': 'Is it possible to access course materials after the course is over?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.7059454)},
#  {'answer_llm': 'Yes, you can prepare for the next cohort after this course completes. All the course materials will be available for you to follow at your own pace, and you can continue working on the homeworks and your final capstone project to prepare for future cohorts.',
#   'answer_orig': 'Yes, we will keep all the materials after the course finishes, so you can follow the course at your own pace after it finishes.\nYou can also continue looking at the homeworks and continue preparing for the next cohort. I guess you can also start working on your final capstone project.',
#   'document': '7bc493b31f7e84ed',
#   'question': 'Can I prepare for the next cohort after this course completes?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.8188136)},
#  {'answer_llm': 'Yes, you are allowed to start working on your capstone project after the course finishes. All the course materials are kept available, and you can begin your project at any time, even after the course has ended.',
#   'answer_orig': 'Yes, we will keep all the materials after the course finishes, so you can follow the course at your own pace after it finishes.\nYou can also continue looking at the homeworks and continue preparing for the next cohort. I guess you can also start working on your final capstone project.',
#   'document': '7bc493b31f7e84ed',
#   'question': 'Am I allowed to start my capstone project after the course finishes?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.7483101)},
#  {'answer_llm': 'Yes, the course materials will be available after the course finishes, so you can follow the course at your own pace later on.',
#   'answer_orig': 'Yes, we will keep all the materials after the course finishes, so you can follow the course at your own pace after it finishes.\nYou can also continue looking at the homeworks and continue preparing for the next cohort. I guess you can also start working on your final capstone project.',
#   'document': '7bc493b31f7e84ed',
#   'question': 'Will the course content be available for selfpaced learning later?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.7430806)},
#  {'answer_llm': 'The CONTEXT provided does not include specific information about the support options available for self-paced course participants. \n\nBased on general knowledge, self-paced course participants typically have access to support through resources such as FAQs, discussion forums, or email support. \n\nHowever, I recommend checking the course platform or contacting the course administrators directly for detailed support options for self-paced participants.',
#   'answer_orig': 'Yes, the slack channel remains open and you can ask questions there. But always sDocker containers exit code w search the channel first and second, check the FAQ (this document), most likely all your questions are already answered here.\nYou can also tag the bot @ZoomcampQABot to help you conduct the search, but don’t rely on its answers 100%, it is pretty good though.',
#   'document': '91c9a4a23d656770',
#   'question': 'What are the support options available for selfpaced course participants?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.20512894)},
#  {'answer_llm': 'Yes, since the course is available in self-paced mode, you can ask questions at any time. You can also participate in live sessions if you choose to join cohort iterations, but self-paced learners can seek help through course forums, FAQ documents, or community support channels.',
#   'answer_orig': 'Yes, the slack channel remains open and you can ask questions there. But always sDocker containers exit code w search the channel first and second, check the FAQ (this document), most likely all your questions are already answered here.\nYou can also tag the bot @ZoomcampQABot to help you conduct the search, but don’t rely on its answers 100%, it is pretty good though.',
#   'document': '91c9a4a23d656770',
#   'question': 'Is there a way to ask questions if Im learning at my own pace?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.36110577)},
#  {'answer_llm': 'If you have questions during the self-paced course, you should start by checking the relevant course-related resources. Specifically, the "General course-related questions" section mentions that frequently asked technical questions are documented, so reviewing that document can be helpful. Additionally, it is recommended to join the course Slack channel (#course-ml-zoomcamp) and the Telegram channel for announcements to stay updated and ask questions there.',
#   'answer_orig': 'Yes, the slack channel remains open and you can ask questions there. But always sDocker containers exit code w search the channel first and second, check the FAQ (this document), most likely all your questions are already answered here.\nYou can also tag the bot @ZoomcampQABot to help you conduct the search, but don’t rely on its answers 100%, it is pretty good though.',
#   'document': '91c9a4a23d656770',
#   'question': 'Where should I look first if I have questions during the selfpaced course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.43658626)},
#  {'answer_llm': "Based on the CONTEXT, you can rely on the provided bot @ZoomcampQABot to help you conduct searches in the course's Slack channel and to find answers. However, it is recommended not to rely on its answers 100% because it is pretty good but may not always be perfect. Additionally, you should always check the FAQ and search the Slack channel first, as most questions are likely already answered there.",
#   'answer_orig': 'Yes, the slack channel remains open and you can ask questions there. But always sDocker containers exit code w search the channel first and second, check the FAQ (this document), most likely all your questions are already answered here.\nYou can also tag the bot @ZoomcampQABot to help you conduct the search, but don’t rely on its answers 100%, it is pretty good though.',
#   'document': '91c9a4a23d656770',
#   'question': 'Can I rely on the provided bot for answers to my course questions?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.61380506)},
#  {'answer_llm': 'To access the year-specific playlist for additional course materials or videos, you can find the dedicated playlist pinned to the Slack channel. Additionally, the course\'s main videos are stored in the "DATA ENGINEERING" playlist on YouTube, and for further customized or year-specific videos (like office hours), you should look for the relevant playlist named for that year, which is also available through the links provided in the course resources.',
#   'answer_orig': 'All the main videos are stored in the Main “DATA ENGINEERING” playlist (no year specified). The Github repository has also been updated to show each video with a thumbnail, that would bring you directly to the same playlist below.\nBelow is the MAIN PLAYLIST’. And then you refer to the year specific playlist for additional videos for that year like for office hours videos etc. Also find this playlist pinned to the slack channel.\nh\nttps://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-',
#   'document': '4908ce096daccb26',
#   'question': 'How can I access the yearspecific playlist for additional course materials or videos?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.85609865)},
#  {'answer_llm': 'The primary YouTube playlist for the course is the "DATA ENGINEERING" playlist, which contains all the main videos. You can access it directly via this link: [https://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-](https://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-)',
#   'answer_orig': 'All the main videos are stored in the Main “DATA ENGINEERING” playlist (no year specified). The Github repository has also been updated to show each video with a thumbnail, that would bring you directly to the same playlist below.\nBelow is the MAIN PLAYLIST’. And then you refer to the year specific playlist for additional videos for that year like for office hours videos etc. Also find this playlist pinned to the slack channel.\nh\nttps://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-',
#   'document': '4908ce096daccb26',
#   'question': 'Can you tell me where I can find the primary YouTube playlist for the course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.71915054)},
#  {'answer_llm': 'The CONTEXT does not specify an exact weekly time commitment for this course.',
#   'answer_orig': 'It depends on your background and previous experience with modules. It is expected to require about 5 - 15 hours per week. [source1] [source2]\nYou can also calculate it yourself using this data and then update this answer.',
#   'document': '5772c84bce84be2b',
#   'question': 'What is the weekly time commitment suggested for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.43416664)},
#  {'answer_llm': 'Based on the provided CONTEXT, you should allocate around 10 hours per week for the course activities.',
#   'answer_orig': 'It depends on your background and previous experience with modules. It is expected to require about 5 - 15 hours per week. [source1] [source2]\nYou can also calculate it yourself using this data and then update this answer.',
#   'document': '5772c84bce84be2b',
#   'question': 'How much time should I allocate each week for the course activities?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.63754064)},
#  {'answer_llm': 'You should use this link to access the main playlist for the Data Engineering course: \n\n[https://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-](https://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&)',
#   'answer_orig': 'All the main videos are stored in the Main “DATA ENGINEERING” playlist (no year specified). The Github repository has also been updated to show each video with a thumbnail, that would bring you directly to the same playlist below.\nBelow is the MAIN PLAYLIST’. And then you refer to the year specific playlist for additional videos for that year like for office hours videos etc. Also find this playlist pinned to the slack channel.\nh\nttps://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-',
#   'document': '4908ce096daccb26',
#   'question': 'What link should I use to access the main playlist for the Data Engineering course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.6257094)},
#  {'answer_llm': "To get help while taking the course independently, the recommended approach is to first try solving problems on your own by reading documentation, searching for solutions online using Google or AI tools like ChatGPT or Bing AI, and checking the tech’s documentation. You can also restart applications or your computer, uninstall and reinstall software, or look for solutions on platforms like Stack Overflow by posting detailed questions that include what you're working on, what error you get, and what you've tried so far. \n\nAdditionally, you can ask in Slack by using the search function, checking the FAQ, and using the @ZoomcampQABot to find answers. When asking in Slack, include as much relevant information as possible and avoid screenshots or tagging instructors. Breaking problems into steps and taking breaks to clear your mind can also help.",
#   'answer_orig': 'Yes, the slack channel remains open and you can ask questions there. But always sDocker containers exit code w search the channel first and second, check the FAQ (this document), most likely all your questions are already answered here.\nYou can also tag the bot @ZoomcampQABot to help you conduct the search, but don’t rely on its answers 100%, it is pretty good though.',
#   'document': '91c9a4a23d656770',
#   'question': 'How can I get help while taking the course independently?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.33145452)},
#  {'answer_llm': 'Yes, there is a specific playlist on YouTube that includes all the main videos for this course. It is called the “DATA ENGINEERING” playlist, and you can find it here: [https://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-](https://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-). The playlist contains all the main videos, and additional year-specific playlists are also available for extra content like office hours.',
#   'answer_orig': 'All the main videos are stored in the Main “DATA ENGINEERING” playlist (no year specified). The Github repository has also been updated to show each video with a thumbnail, that would bring you directly to the same playlist below.\nBelow is the MAIN PLAYLIST’. And then you refer to the year specific playlist for additional videos for that year like for office hours videos etc. Also find this playlist pinned to the slack channel.\nh\nttps://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-',
#   'document': '4908ce096daccb26',
#   'question': 'Is there a specific playlist on YouTube that includes all the essential videos for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.74692714)},
#  {'answer_llm': 'Yes, there is a way to find the office hours videos related to your course on YouTube. All the office hours videos, along with the main pre-recorded course videos, are stored in the course playlist on YouTube. Specifically, you should look for the year-specific playlist that is often pinned to the Slack channel for your cohort. The general main playlist also contains the office hours videos for different years, and you can access it here: https://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-',
#   'answer_orig': 'All the main videos are stored in the Main “DATA ENGINEERING” playlist (no year specified). The Github repository has also been updated to show each video with a thumbnail, that would bring you directly to the same playlist below.\nBelow is the MAIN PLAYLIST’. And then you refer to the year specific playlist for additional videos for that year like for office hours videos etc. Also find this playlist pinned to the slack channel.\nh\nttps://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-',
#   'document': '4908ce096daccb26',
#   'question': 'Is there a way to find the office hours videos related to our course on YouTube?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.70370436)},
#  {'answer_llm': 'Based on the CONTEXT, there is a recommended engagement of around 10 hours per week for the course. Timur Kamaliev conducted a detailed analysis indicating that students of the previous cohort typically spent this amount of time on the course modules and projects.',
#   'answer_orig': 'It depends on your background and previous experience with modules. It is expected to require about 5 - 15 hours per week. [source1] [source2]\nYou can also calculate it yourself using this data and then update this answer.',
#   'document': '5772c84bce84be2b',
#   'question': 'Is there a recommended number of hours per week to engage with the course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.65319884)},
#  {'answer_llm': "Based on the provided CONTEXT, you should expect to dedicate approximately 5 to 15 hours per week to this course, depending on your background and previous experience with the modules. Additionally, a detailed analysis indicates that around 10 hours per week is a typical estimate based on the previous cohort's experience.",
#   'answer_orig': 'It depends on your background and previous experience with modules. It is expected to require about 5 - 15 hours per week. [source1] [source2]\nYou can also calculate it yourself using this data and then update this answer.',
#   'document': '5772c84bce84be2b',
#   'question': 'What factors influence the weekly hours I should expect to dedicate to this course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.77577233)},
#  {'answer_llm': 'No, there are no circumstances under which you can receive a certificate while following the course in self-paced mode. Certificates are only awarded if you finish the course with a “live” cohort, as peer-review of capstone projects is required and can only be done during the course run.',
#   'answer_orig': "No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running.",
#   'document': '286098849c2d928d',
#   'question': 'Are there any circumstances under which I could get certified while following the course selfpaced?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.88781536)},
#  {'answer_llm': 'Based on the CONTEXT, the estimated time investment needed each week for the course is about 5 to 15 hours. Additionally, some students or previous analyses suggest around ~10 hours per week as a typical estimate.',
#   'answer_orig': 'It depends on your background and previous experience with modules. It is expected to require about 5 - 15 hours per week. [source1] [source2]\nYou can also calculate it yourself using this data and then update this answer.',
#   'document': '5772c84bce84be2b',
#   'question': 'Can you give me an estimate of the time investment needed each week for the course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.5627364)},
#  {'answer_llm': "No, you cannot earn a certificate if you complete the course at your own pace. Certificates are only awarded if you finish the course with a “live” cohort, as peer-review of capstones is required and can only be done during the course's scheduled run.",
#   'answer_orig': "No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running.",
#   'document': '286098849c2d928d',
#   'question': 'Is it possible to earn a certificate if I complete the course at my own pace?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.8326205)},
#  {'answer_llm': 'The reason behind not awarding certificates for self-paced course participants is that peer review of capstone projects is a requirement for certification. Peer review can only be conducted when the course is running in a "live" cohort, as students review each other\'s projects during the course period. Since self-paced participants do not participate in this cohort-based review process, certificates are not awarded to them.',
#   'answer_orig': "No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running.",
#   'document': '286098849c2d928d',
#   'question': 'What is the reason behind not awarding certificates for selfpaced course participants?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.7966866)},
#  {'answer_llm': "Yes, peer-reviewing capstone projects impacts the certification process in the course. Specifically, you need to review at least 3 peers' projects for each of the two submitted projects to be eligible for the course certificate.",
#   'answer_orig': "No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running.",
#   'document': '286098849c2d928d',
#   'question': 'Does peerreviewing capstone projects impact the certification process in the course?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.66085553)},
#  {'answer_llm': "Yes, you can receive a certificate upon completion if you take the course independently. To be eligible, you need to submit at least 2 out of 3 course projects and review 3 peers' projects for each submission deadline. However, note that you will not be able to submit some homeworks, but it is still possible to qualify for the certificate by completing the required projects and peer reviews.",
#   'answer_orig': "No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running.",
#   'document': '286098849c2d928d',
#   'question': 'If I take the course independently, can I still receive a certificate upon completion?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.78749835)},
#  {'answer_llm': 'Yes, there is a specific channel where the video URL for the sessions is announced. The video URL is posted in the announcements channel on Telegram and Slack before the session begins.',
#   'answer_orig': 'The zoom link is only published to instructors/presenters/TAs.\nStudents participate via Youtube Live and submit questions to Slido (link would be pinned in the chat when Alexey goes Live). The video URL should be posted in the announcements channel on Telegram & Slack before it begins. Also, you will see it live on the DataTalksClub YouTube Channel.\nDon’t post your questions in chat as it would be off-screen before the instructors/moderators have a chance to answer it if the room is very active.',
#   'document': '791186a6ab40bbfc',
#   'question': 'Is there a specific channel where the video URL for the sessions is announced?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.53518516)},
# ...
#   'answer_orig': 'This tutorial shows you how to set up the Chrome Remote Desktop service on a Debian Linux virtual machine (VM) instance on Compute Engine. Chrome Remote Desktop allows you to remotely access applications with a graphical user interface.\nTaxi Data - Yellow Taxi Trip Records downloading error, Error no or XML error webpage\nWhen you try to download the 2021 data from TLC website, you get this error:\nIf you click on the link, and ERROR 403: Forbidden on the terminal.\nWe have a backup, so use it instead: https://github.com/DataTalksClub/nyc-tlc-data\nSo the link should be https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz\nNote: Make sure to unzip the “gz” file (no, the “unzip” command won’t work for this.)\n“gzip -d file.gz”g',
#   'document': 'a176da578f3b0de0',
#   'question': 'How do I properly extract the contents of a gz file after downloading the taxi trip data?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.10693775)},
#  {'answer_llm': "The CONTEXT provided does not include specific instructions for installing Chrome Remote Desktop on a Debian Linux VM in Google Cloud's Compute Engine. \n\nBased solely on the CONTEXT, I do not have the information to answer your question. However, generally, the steps to install Chrome Remote Desktop on a Debian Linux VM involve:\n\n1. Updating your package list:\n   ```\n   sudo apt update\n   ```\n\n2. Downloading the Chrome Remote Desktop Debian package:\n   ```\n   wget https://dl.google.com/linux/direct/chrome-remote-desktop_current_amd64.deb\n   ```\n\n3. Installing the package:\n   ```\n   sudo apt install ./chrome-remote-desktop_current_amd64.deb\n   ```\n\n4. Installing any necessary dependencies if prompted:\n   ```\n   sudo apt --fix-broken install\n   ```\n\n5. Configuring Chrome Remote Desktop through its setup process, which includes authorizing access via your Google account in the Chrome remote desktop webpage.\n\n6. Setting up a default desktop environment if needed, such as XFCE:\n   ```\n   sudo apt install xfce4\n   ```\n\n7. Starting the Chrome Remote Desktop service.\n\nFor the exact details aligned with a Google Cloud VM environment, including configuring user permissions and desktop environments, I recommend consulting official Google or Chrome Remote Desktop documentation.\n\nWould you like me to look up a detailed step-by-step guide for your specific setup?",
#   'answer_orig': 'This tutorial shows you how to set up the Chrome Remote Desktop service on a Debian Linux virtual machine (VM) instance on Compute Engine. Chrome Remote Desktop allows you to remotely access applications with a graphical user interface.\nTaxi Data - Yellow Taxi Trip Records downloading error, Error no or XML error webpage\nWhen you try to download the 2021 data from TLC website, you get this error:\nIf you click on the link, and ERROR 403: Forbidden on the terminal.\nWe have a backup, so use it instead: https://github.com/DataTalksClub/nyc-tlc-data\nSo the link should be https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz\nNote: Make sure to unzip the “gz” file (no, the “unzip” command won’t work for this.)\n“gzip -d file.gz”g',
#   'document': 'a176da578f3b0de0',
#   'question': 'Can you explain the steps to install Chrome Remote Desktop on a Debian Linux VM in Google Clouds Compute Engine?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.6376175)},
#  {'answer_llm': 'Yes, there is an alternative source for the NYC Taxi Data if you cannot access the TLC website. You can use the backup available on GitHub at this link: https://github.com/DataTalksClub/nyc-tlc-data. For example, the specific data file for January 2021 can be accessed directly via: https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz.',
#   'answer_orig': 'This tutorial shows you how to set up the Chrome Remote Desktop service on a Debian Linux virtual machine (VM) instance on Compute Engine. Chrome Remote Desktop allows you to remotely access applications with a graphical user interface.\nTaxi Data - Yellow Taxi Trip Records downloading error, Error no or XML error webpage\nWhen you try to download the 2021 data from TLC website, you get this error:\nIf you click on the link, and ERROR 403: Forbidden on the terminal.\nWe have a backup, so use it instead: https://github.com/DataTalksClub/nyc-tlc-data\nSo the link should be https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz\nNote: Make sure to unzip the “gz” file (no, the “unzip” command won’t work for this.)\n“gzip -d file.gz”g',
#   'document': 'a176da578f3b0de0',
#   'question': 'Is there an alternative source for the NYC Taxi Data if I cant access the TLC website?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.39968595)},
#  {'answer_llm': 'Based on the provided CONTEXT, to ensure the data file is stored correctly if it ends with csvgz instead of csv, you should parse the filename from the URL and use it directly when reading the file. Specifically, replace the fixed filename (e.g., "output.csv") with the filename extracted from the URL using `csv_name = url.split("/")[-name]`. Since pandas\' `read_csv` can handle files with a `.csv.gz` extension, this approach ensures proper reading of gzipped CSV files without additional unzipping steps.',
#   'answer_orig': 'In this video, we store the data file as “output.csv”. The data file won’t store correctly if the file extension is csv.gz instead of csv. One alternative is to replace csv_name = “output.cs -v” with the file name given at the end of the URL. Notice that the URL for the yellow taxi data is: https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz where the highlighted part is the name of the file. We can parse this file name from the URL and use it as csv_name. That is, we can replace csv_name = “output.csv” with\ncsv_name = url.split(“/”)[-1] . Then when we use csv_name to using pd.read_csv, there won’t be an issue even though the file name really has the extension csv.gz instead of csv since the pandas read_csv function can read csv.gz files directly.',
#   'document': '2a9834fdb7bc1410',
#   'question': 'How can I ensure the data file is stored correctly if it ends with csvgz instead of csv?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.77436787)},
#  {'answer_llm': "Based on the CONTEXT you provided, to utilize the filename from the URL for loading the taxi data correctly, you should:\n\n1. Parse the filename from the URL by splitting it at each '/' and taking the last part:\n   ```python\n   csv_name = url.split('/')[-1]\n   ```\n2. Use this `csv_name` as the filename when reading the data with pandas, such as:\n   ```python\n   pd.read_csv(csv_name)\n   ```\n   \nThis approach ensures that even if the filename includes extensions like `.csv.gz`, pandas can handle the file correctly because it supports reading compressed files directly.",
#   'answer_orig': 'In this video, we store the data file as “output.csv”. The data file won’t store correctly if the file extension is csv.gz instead of csv. One alternative is to replace csv_name = “output.cs -v” with the file name given at the end of the URL. Notice that the URL for the yellow taxi data is: https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz where the highlighted part is the name of the file. We can parse this file name from the URL and use it as csv_name. That is, we can replace csv_name = “output.csv” with\ncsv_name = url.split(“/”)[-1] . Then when we use csv_name to using pd.read_csv, there won’t be an issue even though the file name really has the extension csv.gz instead of csv since the pandas read_csv function can read csv.gz files directly.',
#   'document': '2a9834fdb7bc1410',
#   'question': 'How can I utilize the filename from the URL for loading the taxi data correctly?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.7399846)},
#  {'answer_llm': 'The CONTEXT does not explicitly mention the proper way to save taxi data files when dealing with the csvgz extension. However, based on the common practice shown in the examples, the best approach is to handle the gzipped files correctly by recognizing their extension.\n\nSince gzip-compressed files have the extension ".csv.gz", you should save the taxi data files with that extension to accurately reflect their format. When reading the files programmatically, you can typically use functions like pandas\' `pd.read_csv()` directly on gzipped files by passing the filename, and it will handle decompression.\n\n**Summary:**  \n- Save taxi data files with the `.csv.gz` extension when dealing with gzipped CSV files.  \n- Do not unzip or decompress the file manually before saving if you intend to keep the gzipped format.  \n- When reading the files later, use `pd.read_csv(\'filename.csv.gz\')` which can handle gzip compression automatically.\n\nIf you want to keep the file in gzipped format, ensure it is saved with the `.csv.gz` extension for clarity and proper handling in future steps.',
#   'answer_orig': 'In this video, we store the data file as “output.csv”. The data file won’t store correctly if the file extension is csv.gz instead of csv. One alternative is to replace csv_name = “output.cs -v” with the file name given at the end of the URL. Notice that the URL for the yellow taxi data is: https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz where the highlighted part is the name of the file. We can parse this file name from the URL and use it as csv_name. That is, we can replace csv_name = “output.csv” with\ncsv_name = url.split(“/”)[-1] . Then when we use csv_name to using pd.read_csv, there won’t be an issue even though the file name really has the extension csv.gz instead of csv since the pandas read_csv function can read csv.gz files directly.',
#   'document': '2a9834fdb7bc1410',
#   'question': 'What is the proper way to save taxi data files when dealing with the csvgz extension?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.6225457)},
#  {'answer_llm': 'To rename the taxi data file when it is downloaded from a URL, you can parse the filename from the URL itself and assign it as the local filename. For example, if your URL is `https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz`, you can extract the filename `\'yellow_tripdata_2021-01.csv.gz\'` by splitting the URL string and taking the last part:\n\n```python\nurl = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz"\ncsv_name = url.split(\'/\')[-1]\n```\n\nThis way, you assign the filename dynamically based on the URL, effectively renaming the downloaded file to match its original name or desired name for further processing.',
#   'answer_orig': 'In this video, we store the data file as “output.csv”. The data file won’t store correctly if the file extension is csv.gz instead of csv. One alternative is to replace csv_name = “output.cs -v” with the file name given at the end of the URL. Notice that the URL for the yellow taxi data is: https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz where the highlighted part is the name of the file. We can parse this file name from the URL and use it as csv_name. That is, we can replace csv_name = “output.csv” with\ncsv_name = url.split(“/”)[-1] . Then when we use csv_name to using pd.read_csv, there won’t be an issue even though the file name really has the extension csv.gz instead of csv since the pandas read_csv function can read csv.gz files directly.',
#   'document': '2a9834fdb7bc1410',
#   'question': 'What steps should I take to rename the taxi data file when it is downloaded from a URL?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.6406472)},
#  {'answer_llm': 'The CONTEXT provided does not contain information about the data dictionary for Yellow Taxi trips in New York City. However, based on general knowledge, typically, the data dictionary for NYC Yellow Taxi Trip Data can be found on the NYC TLC (Taxi and Limousine Commission) website or in the documentation accompanying the dataset on the GitHub repository where the data is hosted. \n\nFor precise and official details, I recommend checking the [NYC TLC website](https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page) or the [NYC TLC data GitHub repository](https://github.com/DataTalksClub/nyc-tlc-data), which often includes descriptions of the dataset fields and definitions.',
#   'answer_orig': 'Yellow Trips: https://www1.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf\nGreen Trips: https://www1.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_green.pdf',
#   'document': '2236ef58bedd4b43',
#   'question': 'Where can I find the data dictionary for Yellow Taxi trips in New York City?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.71690917)},
#  {'answer_llm': "The CONTEXT indicates that pandas' `read_csv` function can directly read `.csv.gz` files without issues. Specifically, it states that if you set the filename (e.g., `csv_name`) to the name of a `.csv.gz` file, pandas' `pd.read_csv()` can handle it directly, even though the extension is `.csv.gz`. Therefore, pandas offers the method of reading compressed CSV files in gzip format directly using `pd.read_csv()` without needing to decompress the file beforehand.",
#   'answer_orig': 'In this video, we store the data file as “output.csv”. The data file won’t store correctly if the file extension is csv.gz instead of csv. One alternative is to replace csv_name = “output.cs -v” with the file name given at the end of the URL. Notice that the URL for the yellow taxi data is: https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz where the highlighted part is the name of the file. We can parse this file name from the URL and use it as csv_name. That is, we can replace csv_name = “output.csv” with\ncsv_name = url.split(“/”)[-1] . Then when we use csv_name to using pd.read_csv, there won’t be an issue even though the file name really has the extension csv.gz instead of csv since the pandas read_csv function can read csv.gz files directly.',
#   'document': '2a9834fdb7bc1410',
#   'question': 'What method does pandas offer to read files that are in csvgz format without issues?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.6347108)},
#  {'answer_llm': 'The CONTEXT provided does not contain specific resources dedicated to understanding the Green Taxi trip data. However, it mentions URLs for Yellow Taxi data and discusses processing CSV and Parquet files, but no explicit resource or tutorial for Green Taxi trip data is provided in this context. \n\nIf you need resources on Green Taxi trip data, I recommend consulting online data repositories such as NYC Open Data or the DataTalksClub\'s GitHub repositories, where you can find datasets and related tutorials. Alternatively, searching web resources using terms like "Green Taxi trip dataset NYC" or "Green Taxi trip data tutorial" will yield helpful guides and datasets.',
#   'answer_orig': 'Yellow Trips: https://www1.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf\nGreen Trips: https://www1.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_green.pdf',
#   'document': '2236ef58bedd4b43',
#   'question': 'Is there a resource available for understanding the Green Taxi trip data?',
#   'course': 'data-engineering-zoomcamp',
#   'cosine_score': np.float32(0.5123806)}]

# %%
prompt1_template = """
You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
Your task is to analyze the relevance of the generated answer compared to the original answer provided.
Based on the relevance and similarity of the generated answer to the original answer, you will classify
it as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Original Answer: {answer_orig}
Generated Question: {question}
Generated Answer: {answer_llm}

Please analyze the content and context of the generated answer in relation to the original
answer and provide your evaluation in parsable JSON without using code blocks. Once generated please check is json parsable in python:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

prompt2_template = """
You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
Your task is to analyze the relevance of the generated answer to the given question.
Based on the relevance of the generated answer, you will classify it
as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Question: {question}
Generated Answer: {answer_llm}

Please analyze the content and context of the generated answer in relation to the question
and provide your evaluation in parsable JSON without using code blocks. Once generated please check is json parsable in python:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

# %%
def llm(record):
    prompt = prompt1_template.format(**record)
    client = OpenAIClient(api_key=os.getenv("OPENAI_API_KEY"), model=MODEL)

    # Send the prompt to the OpenAI API
    try:
        client_response = client.chat(query=prompt)
        return client_response
    except RuntimeError:
        pass
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
results = []
for result in make_progress(results_parsed, llm):
    results.append(result)
# Out:
# Building context:   0%|          | 0/189 [00:00<?, ?it/s]

# %%
data = []
for res in results:
    ll_parsed = json.loads(res)
    data.append(ll_parsed)

# %%
df = pd.DataFrame(data)

# %%
df.Relevance.value_counts()/df.shape[0]
# Out:
# Relevance
# RELEVANT           0.407407
# PARTLY_RELEVANT    0.365079
# NON_RELEVANT       0.227513
# Name: count, dtype: float64

# %%
def llm(record):
    prompt = prompt2_template.format(**record)
    client = OpenAIClient(api_key=os.getenv("OPENAI_API_KEY"), model=MODEL)

    # Send the prompt to the OpenAI API
    try:
        client_response = client.chat(query=prompt)
        return client_response
    except RuntimeError:
        pass
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
# Out:
# You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
# Your task is to analyze the relevance of the generated answer compared to the original answer provided.
# Based on the relevance and similarity of the generated answer to the original answer, you will classify
# it as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".
#
# Here is the data for evaluation:
#
# Original Answer: The purpose of this document is to capture frequently asked technical questions
# The exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1
# Subscribe to course public Google Calendar (it works from Desktop only).
# Register before the course starts using this link.
# Join the course Telegram channel with announcements.
# Don’t forget to register in DataTalks.Club's Slack and join the channel.
# Generated Question: What is the starting date for the first live Office Hours session of the course?
# Generated Answer: The starting date for the first live Office Hours session of the course is not specified in the provided CONTEXT.
#
# Please analyze the content and context of the generated answer in relation to the original
# answer and provide your evaluation in parsable JSON without using code blocks:
#
# {
#   "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
#   "Explanation": "[Provide a brief explanation for your evaluation]"
# }
# You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
# Your task is to analyze the relevance of the generated answer compared to the original answer provided.
# Based on the relevance and similarity of the generated answer to the original answer, you will classify
# it as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".
#
# Here is the data for evaluation:
#
# Original Answer: The purpose of this document is to capture frequently asked technical questions
# The exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1
# Subscribe to course public Google Calendar (it works from Desktop only).
# Register before the course starts using this link.
# Join the course Telegram channel with announcements.
# Don’t forget to register in DataTalks.Club's Slack and join the channel.
# Generated Question: What is the starting date for the first live Office Hours session of the course?
# Generated Answer: The starting date for the first live Office Hours session of the course is not specified in the provided CONTEXT.
#
# Please analyze the content and context of the generated answer in relation to the original
# answer and provide your evaluation in parsable JSON without using code blocks:
#
# {
#   "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
#   "Explanation": "[Provide a brief explanation for your evaluation]"
# }

# %%
results = []
for result in make_progress(results_parsed, llm):
    results.append(result)
# Out:
# Building context:   0%|          | 0/189 [00:00<?, ?it/s]

# %%
data = []
for res in results:
    ll_parsed = json.loads(res)
    data.append(ll_parsed)

# %%
df = pd.DataFrame(data)

# %%
df.Relevance.value_counts()/df.shape[0]
# Out:
# Relevance
# RELEVANT           0.439153
# PARTLY_RELEVANT    0.359788
# NON_RELEVANT       0.201058
# Name: count, dtype: float64
